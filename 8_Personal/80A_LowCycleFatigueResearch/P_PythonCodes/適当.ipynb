# %%
# 基本
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import json, sys, csv, math, os, random, copy

# 可視化ライブラリ
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 💕SNAP分析

# %% [markdown]
# ## 🌟

# %%
# 専用
x = [60, 50, 45, 40, 35, 30, 25, 20, 15, 10, 5, 0]
y = [
    
 0.1204,
 0.2317,
 0.3,
 0.4189,
 0.6,
 0.8927,
 1.9,
 3.3948,
 8.0,
 13.1522,
 10000,
 36514.6425]
y = [yy*5 for yy in y]

plt.figure(figsize=(8,4))
plt.yscale('log')
# plt.title(f"500年発生回数", fontname="MS Gothic")
plt.xlabel("最大地動速度 PGV [cm/s]", fontname="MS Gothic")
plt.ylabel("500年で発生する回数 [回]", fontname="MS Gothic")
plt.ylim(1,100)
plt.bar(x, y, width=4, align="center")
# Out:
# <BarContainer object of 12 artists>

# %%
# 専用
# y = [0, 0, 4, 0, 4, 0, 2, 0, 2, 0, 2, 0, 0,]
y = [0, 0, 2, -1, 3, -3, 1, -2, 4, -4, 1, 0, 0]


fig = plt.figure(figsize=(6,4))

ax = fig.add_subplot(111)
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.grid(True)

ax.set_xlim(0,12)
ax.set_ylim(-4,4)

ax.set_xlabel("時間 t [s]", fontname="MS Gothic")
ax.set_ylabel("塑性率 μ [-]", fontname="MS Gothic")
ax.plot(y)

# %%
# 可視化！
ax = plt.figure(figsize=(6, 3)).add_subplot()

ax.plot([1,1000], [3,0.5])
ax.set_xscale('log')
ax.set_title(f"S-N曲線 例", fontname="MS Gothic")
ax.set_xlabel("破断に至るまでのサイクル数 N [回]", fontname="MS Gothic")
ax.set_ylabel("塑性率 μ [-]", fontname="MS Gothic")
ax.set_xlim(1, 1000)
# ax.set_ylim(30, 60)

ax.grid(which='major',color='gray',linestyle='-')
ax.grid(which='minor',color='lightgray',linestyle='-')

plt.show()
